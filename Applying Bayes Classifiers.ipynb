# %% [markdown]
# <a href="https://colab.research.google.com/github/Hrishita-Dalal/CPML24_Projects_and_Labs/blob/main/Applying%20Bayes%20Classifiers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-15 12:06:30--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   178MB/s    in 0.4s
#
# 2025-03-15 12:06:32 (178 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 13162  1710.00264v1  We propose an efficient meta-algorithm for Bay...    cs
# 21838   1305.1998v1  We propose an original model for inferring tea...  stat
# 29110  1708.04503v1  Automatic pathological pulmonary lobe segmenta...    cs
# 30136  1711.07719v1  Multi-Camera arrays are increasingly employed ...    cs
# 35490   0712.3147v2  This paper presents experiments on common know...    cs
# ...             ...                                                ...   ...
# 19968   1303.5721v1  Since exact probabilistic inference is intract...    cs
# 16918  1707.04412v1  Semantic parsing shines at analyzing complex n...    cs
# 12450  1802.03041v1  Machine learning has become an important compo...  stat
# 10269   1011.1518v3  Suppose a given observation matrix can be deco...  stat
# 32992  1512.06900v1  Embedding learning, a.k.a. representation lear...    cs
#
#                                                    title  year  \
# 13162  Bayesian estimation from few samples: communit...  2017
# 21838  Inferring Team Strengths Using a Discrete Mark...  2013
# 29110  Pathological Pulmonary Lobe Segmentation from ...  2017
# 30136  Total Variation-Based Dense Depth from Multi-C...  2017
# 35490  Common knowledge logic in a higher order proof...  2007
# ...                                                  ...   ...
# 19968  Search-based Methods to Bound Diagnostic Proba...  2013
# 16918  Evaluating Semantic Parsing against a Simple W...  2017
# 12450  Detection of Adversarial Training Examples in ...  2018
# 10269          Robust Matrix Decomposition with Outliers  2010
# 32992  Predicting the Co-Evolution of Event and Knowl...  2015
#
#                                                 keywords
# 13162  [efficient, algorithm, estimation, polynomials...
# 21838  [inferring, strengths, historical, estimates, ...
# 29110  [automatic, pathological, pulmonary, clinicall...
# 30136  [increasingly, industrial, applications, techn...
# 35490  [experiments, knowledge, conducted, assistant,...
# ...                                                  ...
# 19968  [probabilistic, inference, intractable, connec...
# 16918  [analyzing, composition, computation, question...
# 12450  [important, component, applications, including...
# 10269  [observation, decomposed, individual, componen...
# 32992  [embedding, representation, knowledge, knowled...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 13162    [efficient, algorithm, estimation, polynomials...
# 21838    [inferring, strengths, historical, estimates, ...
# 29110    [automatic, pathological, pulmonary, clinicall...
# 30136    [increasingly, industrial, applications, techn...
# 35490    [experiments, knowledge, conducted, assistant,...
#                                ...
# 9925     [methodology, computing, processing, informati...
# 27964    [distribution, multimodality, notoriously, reg...
# 25969    [classification, extracting, different, classi...
# 12623    [reinforcement, algorithm, experiment, techniq...
# 34309    [automatic, evaluation, summarization, correla...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8783 words.
# Out of those 4611 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fb4bf834-0b47-42b7-be25-feb366695a52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb4bf834-0b47-42b7-be25-feb366695a52")) {                    Plotly.newPlot(                        "fb4bf834-0b47-42b7-be25-feb366695a52",                        [{"x":["communities","computational","programming","approximate","detection","decomposition","approximation","guarantees","parameters","statistical","conjecture","threshold","posterior","exponential","complexity","conjectured","thresholds","distribution","polynomials","constructions","semidefinite","stochastic","algorithm","strikingly","membership","efficient","estimation","community","performance","estimates","propagation","strengths","defensive","inferring","expectation","optimization","parameter","historical","offensive","professional","discussed","dimensional","inference","maximization","combination","demonstrated","challenges","incomplete","sacrifice","robustness","segmentation","difficult","segmentations","pathological","pulmonary","outperforming","advantages","important","contextual","holistically","significantly","methodological","simplicity","automatic","progressive","boundaries","information","clinically","capability","potential","increased","independence","documented","evaluation","impractical","benchmark","industrial","framework","applications","estimated","deployment","consequence","indicates","significant","generates","variation","equivalent","continuous","algorithms","increasingly","minimization","photorealistic","requirements","processed","techniques","estimations","knowledge","specified","implemented","inductive","furthermore","manifests","conducted","structures","structure","interplay","proposition","assistant","experiments","thousands","effectiveness","inevitably","optimizing","importantly","multilevel","recognition","connections","versatility","respectively","dominates","demonstrate","architecture","particular","synthesis","factorizations","necessary","combinations","presented","describes","empirical","represented","representation","acquisition","procedure","underlying","therefore","available","minimizing","dictionary","pheromone","particularly","practical","arguments","implications","mechanism","designmethodologyapproach","algorithmic","attraction","experimental","consistently","behaviour","theoretical","situations","spatially","repulsion","configuration","distributed","processes","sequentially","different","transferring","predictors","convergence","necessarily","revisited","optimized","challenge","directions","excellent","collaboration","sometimes","inspiring","opportunity","participation","competition","modifications","integrate","incoherence","criterion","extensive","concurrently","constraints","shrinking","eliminate","strengthening","prediction","coherence","supervised","categories","developed","resulting","formulated","expressive","constructed","discriminative","dedicated","character","attention","unfavorable","employing"],"y":[23,289,117,108,368,60,134,60,226,142,14,32,35,43,236,3,5,206,9,9,6,140,818,5,18,399,204,71,937,76,80,24,3,20,30,283,125,28,2,3,71,188,220,29,130,84,114,35,3,107,212,132,17,6,7,34,69,348,54,3,285,4,26,174,5,36,699,13,57,164,42,31,4,268,12,226,25,549,428,62,18,21,26,238,44,61,47,108,578,54,72,3,41,26,349,6,325,39,100,21,169,2,90,129,368,10,9,4,610,27,218,3,46,24,7,370,57,3,87,4,584,249,281,41,3,76,31,182,78,147,82,373,48,115,112,126,278,47,49,2,67,130,13,30,137,2,43,2,355,43,28,157,51,26,2,25,98,110,12,762,15,14,109,20,4,47,172,43,34,14,24,2,13,7,34,21,53,1,51,174,6,151,2,11,3,243,19,194,93,186,156,42,33,52,109,18,49,163,2,30],"type":"bar"},{"x":["communities","computational","programming","approximate","detection","decompositi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4611,), (4611, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Feature</span> <span style=''>Mapping</span> <span style=''>for</span> <span style=''>Learning</span> <span style=''>Fast</span> <span style=''>and</span> <span style=''>Accurate</span> <span style=''>3D</span> <span style=''>Pose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Synthetic</span> <span style=''>Images</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploiting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synthetic</span> <span style=''>images</span> <span style=''>when</span> <span style=''>training</span> <span style=''>a</span> <span style=''>Deep</span> <span style=''>Network</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>a</span> <span style=''>3D</span> <span style=''>pose</span> <span style=''>from</span> <span style=''>an</span> <span style=''>image</span> <span style=''>The</span> <span style=''>ability</span> <span style=''>of</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synthetic</span> <span style=''>images</span> <span style=''>for</span> <span style=''>training</span> <span style=''>a</span> <span style=''>Deep</span> <span style=''>Network</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style=''>valuable</span> <span style=''>as</span> <span style=''>it</span> <span style=''>is</span> <span style=''>easy</span> <span style=''>to</span> <span style=''>create</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>virtually</span> <span style=''>infinite</span> <span style=''>training</span> <span style=''>set</span> <span style=''>made</span> <span style=''>of</span> <span style=''>such</span> <span style=''>images</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.4516129032258065);'>capturing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>annotating</span> <span style=''>real</span> <span style=''>images</span> <span style=''>can</span> <span style=''>be</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>cumbersome</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synthetic</span> <span style=''>images</span> <span style=''>do</span> <span style=''>not</span> <span style=''>resemble</span> <span style=''>real</span> <span style=''>images</span> <span style=''>exactly</span> <span style=''>and</span> <span style=''>using</span> <span style=''>them</span> <span style=''>for</span> <span style=''>training</span> <span style=''>can</span> <span style=''>result</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>suboptimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>It</span> <span style=''>was</span> <span style=''>recently</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>for</span> <span style=''>exemplar</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>mapping</span> <span style=''>from</span> <span style=''>the</span> <span style=''>exemplar</span> <span style='background-color:rgba(0, 255, 0, 0.4114285714285714);'>representations</span> <span style=''>of</span> <span style=''>real</span> <span style=''>images</span> <span style=''>to< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Junction</span> <span style=''>Tree</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Undirected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Graphical</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <br/><br/><span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undirected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style=''>is</span> <span style=''>a</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undirected</span> <span style=''>graph</span> <span style=''>G</span> <span style=''>where</span> <span style=''>the</span> <span style=''>vertices</span> <span style=''>in</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>index</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>and</span> <span style=''>the</span> <span style=''>edges</span> <span style=''>encode</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>among</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undirected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>(UGMS)</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>G</span> <span style=''>given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undirected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposing</span> <span style=''>the</span> <span style=''>UGMS</span> <span style=''>problem</span> <span style=''>into</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subproblems</span> <span style=''>over</span> <span style=''>clusters</span> <span style=''>and</span> <span style=''>subsets</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separators</span> <span style=''>in</span> <span style=''>a</span> <span style=''>junction</span> <span style=''>tree</span> <span style=''>The</span> <span style=''>junction</span> <span style=''>tree</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>using</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>that</span> <span style=''>contains</span> <span style=''>a</span> <span style=''>superset</span> <span style=''>of</span> <span style=''>the</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scaling</span> <span style=''>Limit</span> <span style=''>Exact</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Tractable</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Online</span> <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Applications</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.45985401459854014);'>Regularized</span> <span style='background-color:rgba(255, 0, 0, 0.5263157894736843);'>Regression</span> <span style=''>and</span> <span style=''>PCA</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analyzing</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style=''>online</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3285714285714285);'>dimensional</span> <span style=''>scaling</span> <span style=''>limit</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>are</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>two</span> <span style=''>concrete</span> <span style=''>examples</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.45985401459854014);'>regularized</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.5263157894736843);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>As</span> <span style=''>the</span> <span style=''>ambient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimension</span> <span style=''>tends</span> <span style=''>to</span> <span style=''>infinity</span> <span style=''>and</span> <span style=''>with</span> <span style=''>proper</span> <span style=''>time</span> <span style=''>scaling</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>time</span> <span style=''>varying</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>measures</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>feature</span> <span style=''>vector</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3122171945701357);'>estimates</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>will</span> <span style=''>converge</span> <span style=''>weakly</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style=''>measured</span> <span style=''>valued</span> <span style=''>process</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterized</span> <span style=''>as</span> <span style=''>the</span> <span style=''>unique</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.32947976878612717);'>nonlinear</span> <span style=''>PDE</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Mean</span> <span style=''>Actor</span> <span style=''>Critic</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>Mean</span> <span style=''>Actor</span> <span style=''>Critic</span> <span style=''>(MAC)</span> <span style=''>for</span> <span style=''>discrete</span> <span style=''>action</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>state</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>MAC</span> <span style=''>is</span> <span style=''>a</span> <span style=''>policy</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>agents</span> <span style=''>explicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>all</span> <span style=''>action</span> <span style=''>values</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>of</span> <span style=''>the</span> <span style=''>policy</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>using</span> <span style=''>only</span> <span style=''>the</span> <span style=''>actions</span> <span style=''>that</span> <span style=''>were</span> <span style=''>actually</span> <span style=''>executed</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>reduces</span> <span style=''>variance</span> <span style=''>in</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>updates</span> <span style=''>and</span> <span style=''>removes</span> <span style=''>the</span> <span style=''>need</span> <span style=''>for</span> <span style=''>a</span> <span style=''>variance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>baseline</span> <span style=''>We</span> <span style=''>show</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>results</span> <span style=''>on</span> <span style=''>two</span> <span style=''>control</span> <span style=''>domains</span> <span style=''>where</span> <span style=''>MAC</span> <span style=''>performs</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>or</span> <span style=''>better</span> <span style=''>than</span> <span style=''>other</span> <span style=''>policy</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>and</span> <span style=''>on</span> <span style=''>five</span> <span style=''>Atari</span> <span style=''>games</span> <span style=''>where</span> <span style=''>MAC</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>with</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>policy</span> <span style=''>search</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09602293084915801)
# 	knowledge (0.11644571838050878)
# 	representation (0.1336438552490147)
# 	architecture (0.08921533500537442)
# 	segmentation (0.07595843783590112)
# 	information (0.2504478681476173)
# 	different (0.27302042278753136)
# 	detection (0.13185238265854532)
# 	convolutional (0.12396990326048012)
# 	recognition (0.13256897169473308)
#
# Some Statistics words are:
# 	optimization (0.18865107018417124)
# 	theoretical (0.1483325037332006)
# 	variables (0.14733698357391736)
# 	statistical (0.15082130413140865)
# 	estimation (0.17421602787456447)
# 	algorithm (0.3957192633150821)
# 	distribution (0.18815331010452963)
# 	dimensional (0.18516674962667995)
# 	inference (0.19761075161772026)
# 	regression (0.187655550024888)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ace5bdc8-0d17-4844-ad33-aba77fa3527f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ace5bdc8-0d17-4844-ad33-aba77fa3527f")) {                    Plotly.newPlot(                        "ace5bdc8-0d17-4844-ad33-aba77fa3527f",                        [{"x":["communities","computational","programming","approximate","detection","decomposition","approximation","guarantees","parameters","statistical","conjecture","threshold","posterior","exponential","complexity","conjectured","thresholds","distribution","polynomials","constructions","semidefinite","stochastic","algorithm","strikingly","membership","efficient","estimation","community","performance","estimates","propagation","strengths","defensive","inferring","expectation","optimization","parameter","historical","offensive","professional","discussed","dimensional","inference","maximization","combination","demonstrated","challenges","incomplete","sacrifice","robustness","segmentation","difficult","segmentations","pathological","pulmonary","outperforming","advantages","important","contextual","holistically","significantly","methodological","simplicity","automatic","progressive","boundaries","information","clinically","capability","potential","increased","independence","documented","evaluation","impractical","benchmark","industrial","framework","applications","estimated","deployment","consequence","indicates","significant","generates","variation","equivalent","continuous","algorithms","increasingly","minimization","photorealistic","requirements","processed","techniques","estimations","knowledge","specified","implemented","inductive","furthermore","manifests","conducted","structures","structure","interplay","proposition","assistant","experiments","thousands","effectiveness","inevitably","optimizing","importantly","multilevel","recognition","connections","versatility","respectively","dominates","demonstrate","architecture","particular","synthesis","factorizations","necessary","combinations","presented","describes","empirical","represented","representation","acquisition","procedure","underlying","therefore","available","minimizing","dictionary","pheromone","particularly","practical","arguments","implications","mechanism","designmethodologyapproach","algorithmic","attraction","experimental","consistently","behaviour","theoretical","situations","spatially","repulsion","configuration","distributed","processes","sequentially","different","transferring","predictors","convergence","necessarily","revisited","optimized","challenge","directions","excellent","collaboration","sometimes","inspiring","opportunity","participation","competition","modifications","integrate","incoherence","criterion","extensive","concurrently","constraints","shrinking","eliminate","strengthening","prediction","coherence","supervised","categories","developed","resulting","formulated","expressive","constructed","discriminative","dedicated","character","attention","unfavorable","employing","elegantly","alternative","correlation","elaborate","representations","outperforms","researches","regularization","artificial","monitoring","committee","diversity","condition","transformer","perceptron","classification","similarity","individual","attributed","qualitative","preferences","efficiently","preference","statements","formalism","faithfully","conditional","reasoning","uniformly","consistency","semantics","improving","connected","starcraft","suggesting","approaches","reinforcement","environment","introduces","curriculum","convolutional","generated","scenarios","development","procedurally","refinement","appearances","capturing","previously","articulated","challenging","dependent","regressing","ambiguous","viewpoints","extract ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	covariates
# 	shattering
# 	explodingvanishing
# 	affirmative
# 	prominently
# 	composers
# 	dependences
# 	confounders
# 	confounder
# 	autoencoding
# 	oscillations
# 	davenport
# 	neuroscientists
# 	psychiatry
# 	borderline
# 	objectively
# 	homoscedastic
# 	definiteness
# 	cytometry
# 	acceptancerejection
# Some words which never appear in Statistics papers:
# 	conjectured
# 	holistically
# 	photorealistic
# 	proposition
# 	assistant
# 	pheromone
# 	designmethodologyapproach
# 	inspiring
# 	strengthening
# 	transformer
# 	starcraft
# 	procedurally
# 	articulated
# 	assembled
# 	monocular
# 	occlusions
# 	propositional
# 	inputoutput
# 	connectionist
# 	radiologists

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.074936195073952e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
